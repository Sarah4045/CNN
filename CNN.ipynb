# %% [markdown]
# <a href="https://colab.research.google.com/github/Sarah4045/CNN/blob/main/CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install unrar -y  # فقط أول مرة
# !unrar x /content/Angry.rar /content/Angry/

# %%
import tensorflow as tf
import keras,os,cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
import cv2
import matplotlib.pyplot as plt

# عرض أول صورة مثلاً
img_path = os.path.join(image_path, images[0])
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis('off')
plt.show()

# %%
image_path = '/content/Angry/Angry'
images = os.listdir(image_path)
print(images)
# Out:
# ['86.jpg', 'aug-139-82.jpg', 'aug-119-57.jpg', 'aug-44-57.jpg', 'aug-92-24.jpg', 'aug-98-30.jpg', 'aug-13-20.jpg', '46.jpg', 'aug-132-74.jpg', 'aug-114-52.jpg', 'aug-162-19.jpg', 'aug-133-76.jpg', '87.jpg', 'aug-137-80.jpg', 'aug-118-56.jpg', '94.jpg', '77.jpg', 'aug-99-31.jpg', 'aug-126-68.jpg', 'aug-46-59.jpg', 'aug-146-91.jpg', '32.jpg', '45.jpg', 'aug-50-67.jpg', 'aug-18-25.jpg', 'aug-20-27.jpg', 'aug-102-36.jpg', 'aug-9-16.jpg', '67.jpg', 'aug-96-28.jpg', '91.jpg', 'aug-156-09.jpg', '68.jpg', '41.jpg', '92.jpg', 'aug-90-22.jpg', 'aug-130-72.jpg', 'aug-26-35.jpg', 'aug-43-56.jpg', '31.jpg', 'aug-173-30.jpg', 'aug-0-02.jpg', '61.jpg', 'aug-17-24.jpg', 'aug-161-18.jpg', 'aug-6-09.jpg', 'aug-80-08.jpg', '17.jpg', 'aug-170-27.jpg', 'aug-27-36.jpg', '83.jpg', '82.jpg', 'aug-49-63.jpg', 'aug-4-06.jpg', 'aug-164-21.jpg', 'aug-85-17.jpg', 'aug-78-05.jpg', 'aug-154-06.jpg', '36.jpg', 'aug-106-42.jpg', 'aug-23-30.jpg', 'aug-160-17.jpg', 'aug-40-53.jpg', 'aug-127-69.jpg', '81.jpg', '60.jpg'
# ...

# %%
len(images)
# Out:
# 250

# %%
images[0]
# Out:
# '86.jpg'

# %%
img=cv2.imread(os.path.join(image_path,images[0]))
img
# Out:
# array([[[106, 187, 225],
#         [108, 189, 227],
#         [107, 183, 225],
#         ...,
#         [ 86,  39,   7],
#         [ 89,  40,   8],
#         [100,  51,  19]],
#
#        [[112, 193, 231],
#         [109, 190, 228],
#         [104, 180, 222],
#         ...,
#         [ 96,  49,  17],
#         [104,  55,  23],
#         [ 83,  34,   2]],
#
#        [[ 95, 175, 216],
#         [128, 208, 249],
#         [103, 179, 221],
#         ...,
#         [ 90,  43,  11],
#         [ 77,  30,   0],
#         [ 88,  41,   9]],
#
#        ...,
#
#        [[ 75, 108, 153],
#         [ 92, 125, 170],
#         [ 73, 102, 146],
#         ...,
#         [ 61, 155, 214],
#         [ 50, 144, 203],
#         [ 63, 157, 216]],
#
#        [[ 84, 117, 162],
#         [ 64,  97, 142],
#         [ 75, 104, 148],
#         ...,
#         [ 58, 152, 211],
#         [ 65, 159, 218],
#         [ 56, 153, 211]],
#
#        [[ 74, 107, 152],
#         [ 96, 129, 174],
#         [ 99, 128, 172],
# ...

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img[0]
# Out:
# array([[106, 187, 225],
#        [108, 189, 227],
#        [107, 183, 225],
#        [100, 176, 218],
#        [109, 181, 223],
#        [113, 185, 227],
#        [122, 195, 239],
#        [110, 185, 229],
#        [110, 185, 229],
#        [111, 190, 233],
#        [ 89, 168, 211],
#        [ 98, 180, 222],
#        [107, 187, 228],
#        [104, 184, 225],
#        [110, 189, 230],
#        [103, 179, 221],
#        [110, 180, 220],
#        [115, 184, 224],
#        [122, 191, 230],
#        [122, 191, 230],
#        [124, 193, 232],
#        [121, 190, 229],
#        [134, 202, 239],
#        [127, 195, 232],
#        [108, 176, 211],
#        [129, 197, 232],
#        [125, 189, 224],
#        [121, 185, 220],
#        [143, 205, 241],
#        [131, 193, 229],
#        [143, 205, 241],
#        [125, 187, 223],
#        [135, 199, 234],
#        [121, 185, 220],
#        [152, 214, 250],
#        [129, 191, 227],
#        [144, 207, 241],
#        [149, 212, 246],
# ...

# %%
img[0][0]
# Out:
# array([106, 187, 225], dtype=uint8)

# %%
img.shape
# Out:
# (224, 224, 3)

# %%
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
img.shape
# Out:
# (224, 224)

# %%
img[0]
# Out:
# array([189, 191, 187, 180, 185, 189, 200, 190, 190, 194, 172, 183, 190,
#        187, 192, 183, 184, 188, 195, 195, 197, 194, 205, 198, 179, 200,
#        192, 188, 209, 197, 209, 191, 202, 188, 218, 195, 210, 215, 207,
#        196, 198, 200, 213, 201, 203, 207, 210, 192, 212, 225, 208, 212,
#        223, 212, 209, 207, 208, 205, 202, 193, 208, 219, 217, 199, 212,
#        206, 208, 210, 211, 215, 209, 201, 207, 206, 210, 221, 220, 211,
#        207, 223, 215, 217, 205, 213, 207, 222, 209, 204, 211, 201, 213,
#        210, 209, 209, 214, 209, 211, 217, 219, 207, 209, 203, 215, 195,
#        203, 200, 207, 222, 215, 196, 220, 210, 201, 209, 203, 217, 208,
#        197, 194, 191, 198, 202, 196, 196, 180, 196, 192, 167, 170, 173,
#        151, 148, 117, 139, 100,  96,  90,  90,  85,  56,  51,  74,  57,
#         47,  47,  33,  33,  44,  33,  46,  44,  31,  38,  27,  36,  28,
#         34,  23,  36,  35,  28,  38,  39,  34,  47,  30,  43,  32,  39,
# ...

# %%
plt.imshow(img, cmap='gray')
plt.show()

# %%
np.random.choice([1,2,5,6,9,8,5,6,3])
# Out:
# np.int64(5)

# %%
for i in range(5) :
  img=cv2.imread(os.path.join(image_path,np.random.choice(images)))
  plt.imshow(img)
  plt.show()

# %%
for i in range(5) :
  img=cv2.imread(os.path.join(image_path,np.random.choice(images)))
  img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  plt.imshow(img, cmap='gray')
  plt.show()

# %%
AllSizes = []
for img in  os.listdir(image_path) :
  img=cv2.imread(os.path.join(image_path,img))
  AllSizes.append(img.shape)
set(AllSizes)
# Out:
# {(179, 179, 3), (224, 224, 3)}

# %%
W,H = 80 ,100
for i in range(5) :
  img=cv2.imread(os.path.join(image_path,np.random.choice(images)))
  img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
  img = cv2.resize(img, (H,W))
  plt.imshow(img, cmap='gray')
  plt.show()

# %%
img
# Out:
# array([[ 68,  67,  67, ..., 157, 152, 143],
#        [ 71,  70,  69, ..., 145, 142, 134],
#        [ 72,  71,  71, ..., 128, 125, 117],
#        ...,
#        [ 63,  36,  52, ..., 191, 189, 189],
#        [ 62,  28,  41, ..., 177, 184, 199],
#        [ 50,  20,  21, ..., 179, 174, 193]], dtype=uint8)

# %%
img.shape
# Out:
# (80, 100)

# %%
img = img.reshape(80,100,1)
img.shape
# Out:
# (80, 100, 1)

# %%
ImagesArray = []
W,H = 80 ,100
for img in os.listdir(image_path):
  img = cv2.imread(os.path.join(image_path,img) ,cv2.IMREAD_GRAYSCALE)
  img = cv2.resize(img, (H,W))
  img = img.reshape(H,W,1)
  ImagesArray.append(img)
len(ImagesArray)
# Out:
# 250

# %%
y = [np.random.choice([0,1]) for i in range(250)]
y
# Out:
# [np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(0),
#  np.int64(0),
#  np.int64(1),
#  np.int64(1),
# ...

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(np.array(ImagesArray), np.array(y), test_size=0.25, random_state=44, shuffle =True)

print('X_train shape is ' , X_train.shape)
print('X_test shape is ' , X_test.shape)
print('y_train shape is ' , y_train.shape)
print('y_test shape is ' , y_test.shape)
# Out:
# X_train shape is  (187, 100, 80, 1)
# X_test shape is  (63, 100, 80, 1)
# y_train shape is  (187,)
# y_test shape is  (63,)

# %%
KerasModel = keras.models.Sequential([
        keras.layers.Conv2D(filters = 32, kernel_size = (3,3),strides = (1,1), padding = 'VALID' ,input_shape = (H,W,1)),# SAME
        keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),
        keras.layers.BatchNormalization(),
        keras.layers.Conv2D(filters = 32, kernel_size = (4,4),strides = (1,1), padding = 'VALID'  ),
        keras.layers.MaxPooling2D(pool_size = (2,2), strides = (2,2)),
        keras.layers.BatchNormalization(),
        keras.layers.Flatten(),
        keras.layers.Dense(128, activation = tf.nn.relu),
        keras.layers.Dropout(0.2),
        keras.layers.Dense(1, activation = tf.nn.sigmoid),
        ])
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
KerasModel.compile(optimizer ='adam',loss='binary_crossentropy',metrics=['accuracy'])

# %%
KerasModel.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 345ms/step - accuracy: 0.4749 - loss: 4.5021
# Epoch 2/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 332ms/step - accuracy: 0.6411 - loss: 2.9964
# Epoch 3/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 393ms/step - accuracy: 0.7599 - loss: 1.4715
# Epoch 4/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 473ms/step - accuracy: 0.8457 - loss: 0.4051
# Epoch 5/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 4s 324ms/step - accuracy: 0.9136 - loss: 0.3802
# Epoch 6/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 324ms/step - accuracy: 0.9243 - loss: 0.1764
# Epoch 7/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 2s 330ms/step - accuracy: 0.9524 - loss: 0.0782
# Epoch 8/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 5s 689ms/step - accuracy: 0.9623 - loss: 0.0900
# Epoch 9/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 327ms/step - accuracy: 0.9756 - loss: 0.0735
# Epoch 10/10
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 3s 338ms/step - accuracy: 0.9650 - loss: 0.0735

# %%
print(KerasModel.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 98, 78, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 49, 39, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 49, 39, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 46, 36, 32)     │        16,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...
